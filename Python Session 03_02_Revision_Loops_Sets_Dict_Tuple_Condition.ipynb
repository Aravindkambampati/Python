# %%
MCQ - While Loop
In Python, which keyword is used to define a "while" loop?
a) while
b) loop
c) for
d) iterate

What is the purpose of a "while" loop in Python?
a) To execute a block of code a specified number of times.
b) To iterate through elements in a list or array.
c) To repeatedly execute a block of code as long as a condition is true.
d) To execute a block of code just once.

How do you exit a "while" loop prematurely in Python?
a) Use the "end" keyword.
b) Use the "break" statement.
c) Change the loop condition to False.
d) Use the "continue" statement.

In Python, when is the loop condition in a "while" loop checked?
a) Before entering the loop.
b) After each iteration of the loop.
c) Only at the end of the loop.
d) The loop condition is never checked.

What is the purpose of the "continue" statement in a Python "while" loop?
a) It exits the loop prematurely.
b) It skips the rest of the current iteration and continues with the next iteration.
c) It changes the loop condition.
d) It restarts the loop from the beginning.

How can you create an infinite loop in Python?
a) By using a "for" loop.
b) By setting the loop condition to False.
c) By omitting the loop condition entirely.
d) By using the "pass" statement.

Which of the following statements is used to increment a variable in a Python "while" loop?
a) i++
b) i += 1
c) i = i + 1
d) All of the above

What is the result of running an empty "while" loop in Python?
a) It raises an error.
b) It executes once.
c) It runs indefinitely.
d) It depends on the loop condition.

In Python, how can you ensure that a "while" loop executes at least once even if the condition is initially False?
a) Use a "for" loop instead.
b) Add an "if" statement before the loop.
c) Use a "do-while" loop.
d) Use a "while" loop with the condition inverted.

In Python, what is the primary purpose of the "else" block in a "while" loop?
a) To define loop conditions.
b) To handle exceptions.
c) To execute code after the loop finishes normally.
d) To exit the loop prematurely.

# %%
MCQ: For Loop
    
What is the primary purpose of a for loop in programming?
a. To declare variables
b. To execute a block of code repeatedly
c. To define functions
d. To perform mathematical calculations


Which keyword is commonly used to define a for loop in Python?
a. loop
b. while
c. repeat
d. for


How many times will the following loop iterate?

for i in range(3, 8):
    print(i)
    
a. 3 times
b. 4 times
c. 5 times
d. 6 times

In a for loop, what does the 'range' function do in Python?
a. Generates a random number
b. Specifies the loop condition
c. Creates a list of numbers to iterate over
d. Defines the loop variable


Which statement is used to exit a for loop prematurely in Python?
a. break
b. exit
c. stop
d. end

What is the output of the following loop?

for i in range(2, 6, 2):
    print(i)
    
a. 2, 3, 4, 5
b. 2, 4, 6
c. 2, 2, 2, 2
d. 2, 5


Which programming construct allows you to iterate over the elements of an array or collection in most programming languages?
a. if-else statement
b. while loop
c. for loop
d. switch case statement


In a for loop, what is the role of the loop variable?
a. It defines the range of the loop.
b. It determines the number of iterations.
c. It stores the result of each iteration.
d. It represents the current iteration count.


Which of the following is true about the initialization of loop variables in a for loop?
a. It is not required.
b. It must always be a positive integer.
c. It can be any valid data type.
d. It is handled automatically by the compiler.


What is the purpose of the "continue" statement in a for loop?
a. To exit the loop immediately
b. To skip the current iteration and continue with the next
c. To restart the loop from the beginning
d. To print a message and continue the loop


Which of the following statements is true about the loop variable's scope in a for loop?
a. It has global scope.
b. It has local scope only within the loop.
c. It has block scope.
d. It has function scope.


How can you create an infinite loop using a for loop in Python?
a. Use a negative range
b. Omit the loop condition
c. Set the loop increment to 0
d. It is not possible with a for loop


What is the purpose of the "enumerate" function in Python when used with a for loop?
a. It calculates the sum of elements in a list.
b. It generates a sequence of numbers.
c. It iterates over both the index and value of elements in an iterable.
d. It reverses the order of iteration.

Example:

fruits = ["apple", "banana", "cherry"]
for index, fruit in enumerate(fruits):
    print(index, fruit)
    
In Python, how can you iterate through the characters of a string using a for loop?
a. Use the "for character in string" syntax.
b. Strings cannot be iterated using a for loop.
c. Use a while loop instead.
d. Use the "split" function.


What is the output of the following loop?


for i in range(4):
    for j in range(3):
        print(i, j)
        
a. Prints the numbers 0 to 11
b. Prints the numbers 0 to 3 four times
c. Prints the numbers 0 to 3 twelve times
d. Prints nothing


In a for loop, how can you iterate through the elements of a list in Python?
a. Use the "for i in list" syntax.
b. Use the "for index, value in enumerate(list)" syntax.
c. Use the "for element in list" syntax.
d. Use the "foreach element in list" syntax.


How can you create a nested for loop in Python?
a. By using a single "for" keyword
b. By defining two separate for loops in sequence
c. By using the "nested" keyword
d. By using the "parallel" keyword


Which of the following is true regarding the loop variable in a for loop?
a. The loop variable must always be of type integer.
b. The loop variable can be any valid identifier.
c. The loop variable cannot be modified within the loop.
d. The loop variable must be declared outside of the loop.

# %%
Sets:

Which of the following data structures in Python represents an unordered collection of unique elements?
a. List
b. Tuple
c. Set
d. Dictionary

What is the result of the following set operation: set1 = {1, 2, 3} and set2 = {3, 4, 5}?

set1.union(set2)

a. {1, 2, 3, 4, 5}
b. {1, 2, 3}
c. {3}
d. {4, 5}

Which method is used to add an element to a set in Python?
a. add()
b. append()
c. insert()
d. update()

What is the purpose of the discard() method for sets?
a. To remove an element from the set by value
b. To remove the last element from the set
c. To check if an element is in the set
d. To create a new set

Tuples:

Tuples are mutable in Python.
a. True
b. False

What is the primary difference between a tuple and a list in Python?
a. Tuples can contain duplicate elements, but lists cannot.
b. Tuples are ordered, while lists are not.
c. Tuples are immutable, while lists are mutable.
d. Tuples can have a variable number of elements, while lists have a fixed number.

How do you access elements of a tuple in Python?
a. Using square brackets []
b. Using parentheses ()
c. Using curly braces {}
d. Using angle brackets <>

Which of the following operations creates a new tuple by combining two existing tuples in Python?
a. tuple1 + tuple2
b. tuple1 - tuple2
c. tuple1 * 2
d. tuple1 / tuple2

General Set and Tuple Questions:

In Python, can a set contain duplicate elements?
a. Yes
b. No

What is the output of the len() function when applied to a set containing three elements?
a. 0
b. 1
c. 2
d. 3

What is the primary advantage of using tuples over lists in certain situations?
a. Tuples can be modified after creation.
b. Tuples are faster for element retrieval.
c. Tuples can store elements of different data types.
d. Tuples have more built-in methods.

What is the result of the following code?


my_tuple = (1, 2, 3)
my_tuple[1] = 4

a. The code will raise an error.
b. my_tuple will be updated to (1, 4, 3).
c. my_tuple will be updated to (1, 2, 4).
d. my_tuple will remain unchanged.

Which data structure is more suitable for storing an ordered sequence of elements when the sequence should not be changed after creation?
a. Set
b. Tuple
c. List
d. Dictionary

What is the result of the following set operation: set1 = {1, 2, 3} and set2 = {2, 3, 4}?


set1.intersection(set2)

a. {1, 2, 3}
b. {2, 3}
c. {4}
d. {}

How can you check if an element exists in a tuple in Python?
a. Using the exists() function
b. Using the contains() keyword
c. Using the in operator
d. Using the has() method

Which of the following is a valid way to create an empty set in Python?
a. empty_set = {}
b. empty_set = set()
c. empty_set = set([])
d. empty_set = {None}

What is the result of the following code?

my_set = {1, 2, 3}
my_set.add(3)
my_set.add(4)

a. {1, 2, 3, 4}
b. {1, 2, 3}
c. {2, 3, 4}
d. {1, 2, 3, 3, 4}

Can a tuple be used as a dictionary key in Python?
a. Yes
b. No

What is the primary benefit of using sets in Python?
a. Sets preserve the order of elements.
b. Sets allow duplicate elements.
c. Sets ensure that elements are unique.
d. Sets are more memory-efficient than lists.

In a tuple, can you change the value of an individual element without creating a new tuple?
a. Yes
b. No
