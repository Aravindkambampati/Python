# %% [markdown]
# ## Revision

# %%
What is the symbol for the addition operator in Python?
a. &
b. +
c. *
d. /

Which operator is used for exponentiation in Python?
a. ^
b. **
c. %
d. //

Which of the following operators is used for integer division in Python?
a. %
b. //
c. /
d. *

What does the % operator do in Python?
a. Performs exponentiation
b. Performs integer division
c. Computes the remainder after division
d. Multiplies two numbers

What is the result of the expression 5 + 3 * 2 in Python?
a. 16
b. 11
c. 10
d. 26

Which operator is used to compare if two values are equal in Python?
a. ==
b. =
c. !=
d. <>

What is the result of the expression 7 / 2 in Python?
a. 3.5
b. 3
c. 2.5
d. 4

Which operator is used to check if a value is greater than or equal to another value in Python?
a. >=
b. <=
c. ==
d. >

What is the purpose of the 'and' operator in Python?
a. Bitwise AND operation
b. Logical AND operation
c. Arithmetic addition
d. String concatenation

What does the 'not' operator do in Python?
a. Negates a boolean value
b. Performs bitwise NOT operation
c. Checks if two values are not equal
d. Raises a number to a power

Which operator is used to concatenate strings in Python?
a. &
b. +
c. *
d. /

What is the result of the expression 10 % 3 in Python?
a. 1
b. 0
c. 3.33
d. 10

Which operator is used to slice a sequence like a list or string in Python?
a. ::
b. :
c. ..
d. ;

What is the result of the expression 'hello' * 3 in Python?
a. 'hellohellohello'
b. 'hello3'
c. 'hhh'
d. '3hello'

Which operator is used to check if a value is in a sequence like a list or tuple in Python?
a. in
b. for
c. exists
d. on

What is the result of the expression True and False in Python?
a. True
b. False
c. None
d. Error

What does the 'or' operator do in Python?
a. Bitwise OR operation
b. Logical OR operation
c. String comparison
d. Division

Which operator is used to check if a value is not in a sequence in Python?
a. not in
b. !=
c. <>
d. /=

What is the result of the expression 2 ** 3 ** 2 in Python?
a. 64
b. 512
c. 72
d. 9

What is the result of the expression 5 // 2 in Python?
a. 2.5
b. 2
c. 2.0
d. 2.25

# %%
Identifiers:

What is an identifier in Python?
A. A reserved word in the Python language.
B. A name used to identify variables, functions, classes, and other objects.
C. A data type in Python.
D. An arithmetic operator in Python.


Which of the following is a valid Python identifier?
A. 123identifier
B. my_variable
C. if
D. my-variable


Rules for Identifier Naming:

Which of the following is true regarding Python identifiers?
A. They can contain spaces.
B. They are case-sensitive.
C. They must start with a digit.
D. They can include special characters like '@' and '#'.

Which of the following is a valid Python identifier?
A. my_variable_1
B. 2nd_variable
C. my variable
D. class


Inbuilt Keywords:

What are keywords in Python?
A. User-defined names for variables and functions.
B. Built-in names that have special meanings and cannot be used as identifiers.
C. Reserved names used only in class definitions.
D. Variable names with underscores (e.g., my_variable).


Which of the following is a Python keyword?
A. function
B. print
C. variable
D. 123number


Variables and Data Types:

In Python, variables are:
A. Dynamically typed, meaning their types can change at runtime.
B. Statically typed, meaning their types are fixed and cannot change.
C. Declared using the var keyword.
D. Not allowed.


What is the data type of the variable x in the expression x = 5.5?
A. Integer
B. Float
C. String
D. Boolean


Which data type is used to store a sequence of characters in Python?
A. Integer
B. Float
C. String
D. Boolean


What is the result of the expression 10 / 3 in Python?
A. 3.3333333333333335
B. 3.333333333333333
C. 3.333
D. 3


print() and input():

Which function is used to display output in Python?
A. show()
B. display()
C. output()
D. print()


What does the end parameter in the print() function do?
A. It specifies the character to separate printed items (default is space).
B. It specifies the character to end the printed output (default is a newline).
C. It specifies the number of times to print the output.
D. It specifies the message to print before the output.


Which function is used to take user input in Python?
A. get_input()
B. user_input()
C. input()
D. read_input()


What data type does the input() function return in Python?
A. Integer
B. Float
C. String
D. Boolean


What is the purpose of the argument passed to the input() function?
A. To specify the input prompt.
B. To specify the input data type.
C. To define the variable name for input storage.
D. To control the number of input values.

# %%
MCQ:
    
What is a string in Python?
a) A data type for storing integers
b) A sequence of characters
c) A mathematical operation
d) A way to define functions

How do you create a string in Python?
a) Using the string keyword
b) Enclosing text in double quotes (" ") or single quotes (' ')
c) Using the str() function
d) With the new String() constructor

What is indexing in the context of strings?
a) A way to calculate the length of a string
b) Accessing individual characters in a string using their position
c) The process of converting a string to a number
d) A method for counting vowels in a string

Which of the following is a built-in method for strings in Python?
a) .reverse()
b) .split()
c) .append()
d) .join()

What does the .format() method do for strings?
a) Converts a string to uppercase
b) Removes whitespace from the beginning and end of a string
c) Formats a string by replacing placeholders with values
d) Sorts the characters in a string alphabetically

How can you get user input in Python?
a) Using the input() function
b) Declaring a variable with a user's name
c) Importing the userinput module
d) Using the get_user_input() function

What is type-casting for strings?
a) Converting a string to uppercase
b) Changing a string's data type to integer or other types
c) Casting spells using strings
d) Removing characters from a string

In Python, which of the following characters is used to enclose a string?
a) [ ]
b) { }
c) ( )
d) " " or ' '

What is the result of "Hello, " + "world!" in Python?
a) "Hello, world!"
b) "Hello, "
c) "world!"
d) Error

Which indexing method allows you to access characters from the end of a string?
a) Forward indexing
b) Reverse indexing
c) Dual indexing
d) Negative indexing

What is the output of "Python"[1:4]?
a) "Py"
b) "yth"
c) "tho"
d) "Python"

Which string method is used to find the index of a substring in a string?
a) .index()
b) .find()
c) .search()
d) .locate()

What is the purpose of the .upper() method for strings?
a) Converts all characters to uppercase
b) Converts all characters to lowercase
c) Removes all whitespace
d) Counts the number of uppercase letters

How can you concatenate two strings in Python?
a) Using the * operator
b) Using the + operator
c) Using the - operator
d) Using the / operator

Which of the following is a valid way to convert the string "42" to an integer?
a) int("42")
b) str(42)
c) float("42")
d) 42.toInt()

What is the purpose of the .split() method for strings?
a) Joins two strings together
b) Splits a string into a list of substrings based on a delimiter
c) Removes all spaces from a string
d) Converts a string to uppercase

What does the len() function return for the string "Python"?
a) 5
b) 6
c) 7
d) "Python"

Which method can be used to remove leading and trailing whitespace from a string?
a) .strip()
b) .remove()
c) .clean()
d) .trim()

Which character is used to escape special characters in a string?
a)
b) /
c) &
d) #

Which method is used to replace specific substrings in a string with another substring?
a) .replace()
b) .remove()
c) .insert()
d) .substr()

# %%
MCQ:

What is a list in Python?
a. A data type that can store only integers
b. A data type that can store a collection of items
c. A data type that can store only strings
d. A data type that can store only floating-point numbers

How do you define a list in Python?
a. Using curly braces {}
b. Using square brackets []
c. Using parentheses ()
d. Using angle brackets <>

Which of the following is the correct way to create an empty list?
a. list()
b. []
c. list([])
d. { }

What is indexing in the context of lists?
a. Sorting the elements in a list
b. Accessing the elements of a list using their positions
c. Checking if an element is present in a list
d. Reversing the order of elements in a list

In Python, list indices start at:
a. 0
b. 1
c. -1
d. 2

How do you access the first element of a list?
a. list[0]
b. list[1]
c. list[-1]
d. list[first]

What is slicing in Python lists?
a. Dividing a list into multiple sublists
b. Accessing a range of elements in a list
c. Removing elements from a list
d. Reversing a list

Which of the following slices would extract elements from index 2 to index 5 (inclusive)?
a. list[2:5]
b. list[2:6]
c. list[3:5]
d. list[1:4]

What does the list method append() do?
a. Removes the last element of a list
b. Adds an element to the end of a list
c. Inserts an element at a specified position in a list
d. Sorts the elements in a list

Which list method is used to remove the first occurrence of a value from a list?
a. remove()
b. pop()
c. delete()
d. discard()

What does the len() function return when applied to a list?
a. The number of elements in the list
b. The sum of all elements in the list
c. The maximum element in the list
d. The minimum element in the list

Which of the following list methods can be used to sort a list in ascending order?
a. sort()
b. reverse()
c. append()
d. extend()

What will the expression my_list + [1, 2] do?
a. Concatenate my_list with a new list containing 1 and 2
b. Remove elements 1 and 2 from my_list
c. Add 1 and 2 to the end of my_list
d. Replace my_list with a new list containing 1 and 2

Which of the following list methods can be used to count the number of occurrences of a specific element in a list?
a. count()
b. index()
c. find()
d. locate()

What is the result of my_list.remove(3) if my_list contains [1, 2, 3, 4, 3]?
a. [1, 2, 4, 3]
b. [1, 2, 4]
c. [1, 2, 3, 4]
d. Error, remove() only works with integers.

Which list method is used to remove and return the last element of a list?
a. pop()
b. remove()
c. delete()
d. extract()

What is the purpose of the insert() method in Python lists?
a. Removes an element from a list
b. Appends an element to the end of a list
c. Inserts an element at a specified position in a list
d. Sorts the elements in a list

Which of the following list methods can be used to reverse the order of elements in a list in place (without creating a new list)?
a. reverse()
b. sort()
c. append()
d. extend()

What will the expression my_list[1:4] return if my_list contains [0, 1, 2, 3, 4]?
a. [1, 2, 3]
b. [0, 1, 2]
c. [1, 2, 3, 4]
d. [2, 3, 4]

Which list method is used to clear all the elements from a list?
a. clear()
b. empty()
c. remove()
d. pop()
